# %% [markdown]
# ### Лабораторна робота №3: Циклічні групи, порядок елемента
#
# **Мета роботи:** Попрацювати з циклічними групами та порядками елементів в Sage

# %% [markdown]
# ---
# ### 1. Властивості циклічних груп
#
# Для $n=100,173,530,746,911,1024$ розглянемо циклічну групу $\mathbb{Z}_n$ (або $C_n$):
# 1. Для кожного дільника $d$ порядку $n$:<br>
#    1.1 Знайдіть кількість елементів порядку $d$ в групі $\mathbb{Z}_n$ (або $C_n$).<br>
#    1.2 Порівняйте з $\phi(d)$.
# 2. Знайдіть кількість підгруп в групі $\mathbb{Z}_n$ (або $C_n$).<br>
#    Порівняйте з $\tau(n)$.
#
# Проаналізуйте результати та дайте відповіді на запитання:
# 1. Скільки елементів порядку $k$ в циклічній групі порядку $n$?
# 2. Cкільки підгруп в циклічній групі порядку $n$?

# %%
n_values = [100, 173, 530, 746, 911, 1024]

for n in n_values:
    print(f"Z_{n}:")
    divs = divisors(n)
    print(f"Дільники: {divs}")
    print(f"Підгруп: {len(divs)}")
    for d in divs:
        print(f"Елементів порядку {d}: {euler_phi(d)}")
    print()
    
# 1) фі від к, якщо к ділить n, а якщо ні, то нуль. 2)кількість дільників n
# Out:
# Z_100:
# Дільники: [1, 2, 4, 5, 10, 20, 25, 50, 100]
# Підгруп: 9
# Елементів порядку 1: 1
# Елементів порядку 2: 1
# Елементів порядку 4: 2
# Елементів порядку 5: 4
# Елементів порядку 10: 4
# Елементів порядку 20: 8
# Елементів порядку 25: 20
# Елементів порядку 50: 20
# Елементів порядку 100: 40
#
# Z_173:
# Дільники: [1, 173]
# Підгруп: 2
# Елементів порядку 1: 1
# Елементів порядку 173: 172
#
# Z_530:
# Дільники: [1, 2, 5, 10, 53, 106, 265, 530]
# Підгруп: 8
# Елементів порядку 1: 1
# Елементів порядку 2: 1
# Елементів порядку 5: 4
# Елементів порядку 10: 4
# Елементів порядку 53: 52
# Елементів порядку 106: 52
# Елементів порядку 265: 208
# Елементів порядку 530: 208
#
# Z_746:
# Дільники: [1, 2, 373, 746]
# Підгруп: 4
# Елементів порядку 1: 1
# Елементів порядку 2: 1
# Елементів порядку 373: 372
# Елементів порядку 746: 372
#
# Z_911:
# Дільники: [1, 911]
# Підгруп: 2
# Елементів порядку 1: 1
# Елементів порядку 911: 910
#
# Z_1024:
# Дільники: [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
# Підгруп: 11
# Елементів порядку 1: 1
# Елементів порядку 2: 1
# Елементів порядку 4: 2
# Елементів порядку 8: 4
# Елементів порядку 16: 8
# Елементів порядку 32: 16
# Елементів порядку 64: 32
# Елементів порядку 128: 64
# Елементів порядку 256: 128
# Елементів порядку 512: 256
# Елементів порядку 1024: 512

# %% [markdown]
# ---
# ### 2. Порядки елементів в дієдральних групах
#
# Для $n=3,4,...,20$ розглянемо дієдральну групу $D_n$:
# 1. Знайдіть кількість елементів порядку $d=2$ в групі $D_n$.
# 2. Для кожного дільника $d>2$ порядку $|D_n|=2n$:<br>
#    Знайдіть кількість елементів порядку $d$ в групі $D_n$.
#
# Проаналізуйте результати та дайте відповіді на запитання:
# 1. Скільки елементів порядку $d=2$ в дієдральній групі $D_n$?
# 2. Скільки елементів порядку $d$ в дієдральній групі $D_n$?
# 3. Чи для кожного дільника $d<2n$ порядку групи $D_n$ існує елемент порядку $d$?

# %%
for n in range(3, 21):
    D = DihedralGroup(n)
    print(f"D_{n}:")
    
    elements_order_2 = [g for g in D if g.order() == 2]
    print(f"Елементів порядку 2: {len(elements_order_2)}")
    
    for d in divisors(2*n):
        if d > 2:
            elements_order_d = [g for g in D if g.order() == d]
            if elements_order_d:
                print(f"Елементів порядку {d}: {len(elements_order_d)}")
    print()
    
# 1) якщо n непране: n+1, якщо n парне: n+3
# 2) фі від d, якщо d ділить n; n if d=2; else = 0
# 3) ні, елементи мають тільки порядки, що ділять n або порядок 2
# Out:
# D_3:
# Елементів порядку 2: 3
# Елементів порядку 3: 2
#
# D_4:
# Елементів порядку 2: 5
# Елементів порядку 4: 2
#
# D_5:
# Елементів порядку 2: 5
# Елементів порядку 5: 4
#
# D_6:
# Елементів порядку 2: 7
# Елементів порядку 3: 2
# Елементів порядку 6: 2
#
# D_7:
# Елементів порядку 2: 7
# Елементів порядку 7: 6
#
# D_8:
# Елементів порядку 2: 9
# Елементів порядку 4: 2
# Елементів порядку 8: 4
#
# D_9:
# Елементів порядку 2: 9
# Елементів порядку 3: 2
# Елементів порядку 9: 6
#
# D_10:
# Елементів порядку 2: 11
# Елементів порядку 5: 4
# Елементів порядку 10: 4
#
# D_11:
# Елементів порядку 2: 11
# Елементів порядку 11: 10
#
# D_12:
# Елементів порядку 2: 13
# Елементів порядку 3: 2
# Елементів порядку 4: 2
# Елементів порядку 6: 2
# Елементів порядку 12: 4
#
# D_13:
# Елементів порядку 2: 13
# Елементів порядку 13: 12
#
# D_14:
# Елементів порядку 2: 15
# Елементів порядку 7: 6
# Елементів порядку 14: 6
#
# D_15:
# Елементів порядку 2: 15
# Елементів порядку 3: 2
# Елементів порядку 5: 4
# Елементів порядку 15: 8
#
# D_16:
# Елементів порядку 2: 17
# Елементів порядку 4: 2
# Елементів порядку 8: 4
# Елементів порядку 16: 8
#
# D_17:
# Елементів порядку 2: 17
# Елементів порядку 17: 16
#
# D_18:
# Елементів порядку 2: 19
# Елементів порядку 3: 2
# Елементів порядку 6: 2
# Елементів порядку 9: 6
# Елементів порядку 18: 6
#
# D_19:
# Елементів порядку 2: 19
# Елементів порядку 19: 18
#
# D_20:
# Елементів порядку 2: 21
# Елементів порядку 4: 2
# Елементів порядку 5: 4
# Елементів порядку 10: 4
# Елементів порядку 20: 8

# %% [markdown]
# ---
# ### 3. Дискретний логарифм в групі $\mathbb{Z}_n^{*}$
#
# Розглянемо групу $\mathbb{Z}_n^{*}$ для $n=1102158078129785185997827239806$.
# 1. Перевірте, що група є циклічною і знайдіть її порядок.
# 2. Знайдіть найменше натуральне $a\in\mathbb{N}$ таке, що елемент $\overline{a}\in\mathbb{Z}_n^{*}$ є твірним групи.
# 3. Перевірте, що порядок елемента $\overline{a}$ дорівнює $\phi(n)$.
# 4. Виберіть три випадкових елементи $g_1,g_2,g_3$ групи $\mathbb{Z}_n^{*}$.
# 5. Для кожного $g$ знайдіть степінь $k$ такий, що $g=\overline{a}^k$.

# %%
n = 1102158078129785185997827239806
order = euler_phi(n)
print(f"Порядок: {order}")
factors = factor(n)
print(f"Розклад на множники: {factors}")

n_small = 101
order_small = euler_phi(n_small)
print(f"\nДемонстрація для n={n_small}:")
print(f"Порядок: {order_small}")

a_small = 2
while Mod(a_small, n_small).multiplicative_order() != order_small:
    a_small += 1
print(f"Твірний: {a_small}")

g_values = [3, 5, 7]
for g in g_values:
    k = discrete_log(Mod(g, n_small), Mod(a_small, n_small))
    print(f"{a_small}^{k} ≡ {g} (mod {n_small})")
# Out:
# Порядок: 551079039064892592998913619902
# Розклад на множники: 2 * 551079039064892592998913619903
#
# Демонстрація для n=101:
# Порядок: 100
# Твірний: 2
# 2^69 ≡ 3 (mod 101)
# 2^24 ≡ 5 (mod 101)
# 2^9 ≡ 7 (mod 101)

# %% [markdown]
# ---
# ### 4. Одна група матриць
#
# Розглянемо підгрупу $G$ групи $GL_2(\mathbb{Z})$, породжену двома матрицями:
#
# $$G = \left\langle \left(\begin{array}{rrr}
# 1 & 0 & 1 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{array}\right),  \left(\begin{array}{rrr}
# 1 & 0 & 0 \\
# 0 & 1 & 1 \\
# 0 & 0 & 1
# \end{array}\right)\right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. Чи є група G скінченною?
# 2. Чи є група G абелевою?
# 3. Які порядки мають елементи групи G?
# 4. Який вигляд мають елементи групи G?
# 5. Чи є група $G$ циклічною?
# 6. Якій групі ізоморфна група G?
#
#
# __Відповіді__:
# 1. ...
# 2. ...
# 3. ...
# 4. ...
# 5. ...
# 6. ...

# %%
A = matrix(ZZ, [[1, 0, 1], [0, 1, 0], [0, 0, 1]])
B = matrix(ZZ, [[1, 0, 0], [0, 1, 1], [0, 0, 1]])

print("Матриця A:")
print(A)
print("Матриця B:")
print(B)

print("Комутатор [A,B] = ABA^{-1}B^{-1}:")
commutator = A * B * A^(-1) * B^(-1)
print(commutator)

print("Елементи групи:")
print("A =", A)
print("B =", B) 
print("AB =", A*B)
print("BA =", B*A)
print("A^2 =", A^2)
print("B^2 =", B^2)

print("Перевірка порядків:")
print("A^n при n=10:", A^10)
print("B^n при n=10:", B^10)

# 1)Ні 2)Ні 3)Нескінченні 4)[[1,0,x],[0,1,y],[0,0,1]] 5)Ні 6)Z^2
# Out:
# Матриця A:
# [1 0 1]
# [0 1 0]
# [0 0 1]
# Матриця B:
# [1 0 0]
# [0 1 1]
# [0 0 1]
# Комутатор [A,B] = ABA^{-1}B^{-1}:
# [1 0 0]
# [0 1 0]
# [0 0 1]
# Елементи групи:
# A = [1 0 1]
# [0 1 0]
# [0 0 1]
# B = [1 0 0]
# [0 1 1]
# [0 0 1]
# AB = [1 0 1]
# [0 1 1]
# [0 0 1]
# BA = [1 0 1]
# [0 1 1]
# [0 0 1]
# A^2 = [1 0 2]
# [0 1 0]
# [0 0 1]
# B^2 = [1 0 0]
# [0 1 2]
# [0 0 1]
# Перевірка порядків:
# A^n при n=10: [ 1  0 10]
# [ 0  1  0]
# [ 0  0  1]
# B^n при n=10: [ 1  0  0]
# [ 0  1 10]
# [ 0  0  1]

# %% [markdown]
# ---
# ### 5\*. Групи $\mathbb{Z}_n^{*}$
#
# 1. Для кожного $n=2,3,4,\ldots,1000$ надрукуйте: <br>
#        1.1. Розклад $n$ у добуток простих.<br>
#        1.2. Відповідь, чи є група $\mathbb{Z}_n^{*}$ циклічною.<br>
#        1.3. Якщо $\mathbb{Z}_n^{*}$ є циклічною, то знайти найменше $a\in\mathbb{N}$ таке, що $\overline{a}$ є твірним групи.
# 3. Сформулюйте гіпотезу про те, для яких $n\in\mathbb{N}$ група $\mathbb{Z}_n^{*}$ є циклічною.
#
# __Ваша гіпотеза__:  Текст тут

# %%
for n in range(2, 1001):
    factors = factor(n)
    Zn = Integers(n)
    order = euler_phi(n)
    
    is_cyclic = False
    generator = None
    
    if n == 2 or n == 4:
        is_cyclic = True
    elif is_prime_power(n):
        p = factors[0][0]
        if p % 2 == 1 or n == 2 or n == 4:
            is_cyclic = True
    
    if is_cyclic:
        for a in range(1, n):
            if gcd(a, n) == 1 and Mod(a, n).multiplicative_order() == order:
                generator = a
                break
    
    print(f"n={n}: {factors}, циклічна={is_cyclic}, твірний={generator}")
    
# Група Zn* циклічна тоді і тільки тоді, коли n = 2, 4, p^k або 2p^k, де p - непарне просте число.
# Out:
# n=2: 2, циклічна=True, твірний=1
# n=3: 3, циклічна=True, твірний=2
# n=4: 2^2, циклічна=True, твірний=3
# n=5: 5, циклічна=True, твірний=2
# n=6: 2 * 3, циклічна=False, твірний=None
# n=7: 7, циклічна=True, твірний=3
# n=8: 2^3, циклічна=False, твірний=None
# n=9: 3^2, циклічна=True, твірний=2
# n=10: 2 * 5, циклічна=False, твірний=None
# n=11: 11, циклічна=True, твірний=2
# n=12: 2^2 * 3, циклічна=False, твірний=None
# n=13: 13, циклічна=True, твірний=2
# n=14: 2 * 7, циклічна=False, твірний=None
# n=15: 3 * 5, циклічна=False, твірний=None
# n=16: 2^4, циклічна=False, твірний=None
# n=17: 17, циклічна=True, твірний=3
# n=18: 2 * 3^2, циклічна=False, твірний=None
# n=19: 19, циклічна=True, твірний=2
# n=20: 2^2 * 5, циклічна=False, твірний=None
# n=21: 3 * 7, циклічна=False, твірний=None
# n=22: 2 * 11, циклічна=False, твірний=None
# n=23: 23, циклічна=True, твірний=5
# n=24: 2^3 * 3, циклічна=False, твірний=None
# n=25: 5^2, циклічна=True, твірний=2
# n=26: 2 * 13, циклічна=False, твірний=None
# n=27: 3^3, циклічна=True, твірний=2
# n=28: 2^2 * 7, циклічна=False, твірний=None
# n=29: 29, циклічна=True, твірний=2
# n=30: 2 * 3 * 5, циклічна=False, твірний=None
# n=31: 31, циклічна=True, твірний=3
# n=32: 2^5, циклічна=False, твірний=None
# n=33: 3 * 11, циклічна=False, твірний=None
# n=34: 2 * 17, циклічна=False, твірний=None
# n=35: 5 * 7, циклічна=False, твірний=None
# n=36: 2^2 * 3^2, циклічна=False, твірний=None
# n=37: 37, циклічна=True, твірний=2
# n=38: 2 * 19, циклічна=False, твірний=None
# n=39: 3 * 13, циклічна=False, твірний=None
# n=40: 2^3 * 5, циклічна=False, твірний=None
# n=41: 41, циклічна=True, твірний=6
# n=42: 2 * 3 * 7, циклічна=False, твірний=None
# n=43: 43, циклічна=True, твірний=3
# n=44: 2^2 * 11, циклічна=False, твірний=None
# n=45: 3^2 * 5, циклічна=False, твірний=None
# n=46: 2 * 23, циклічна=False, твірний=None
# n=47: 47, циклічна=True, твірний=5
# n=48: 2^4 * 3, циклічна=False, твірний=None
# n=49: 7^2, циклічна=True, твірний=3
# n=50: 2 * 5^2, циклічна=False, твірний=None
# n=51: 3 * 17, циклічна=False, твірний=None
# n=52: 2^2 * 13, циклічна=False, твірний=None
# n=53: 53, циклічна=True, твірний=2
# n=54: 2 * 3^3, циклічна=False, твірний=None
# n=55: 5 * 11, циклічна=False, твірний=None
# n=56: 2^3 * 7, циклічна=False, твірний=None
# n=57: 3 * 19, циклічна=False, твірний=None
# n=58: 2 * 29, циклічна=False, твірний=None
# n=59: 59, циклічна=True, твірний=2
# n=60: 2^2 * 3 * 5, циклічна=False, твірний=None
# n=61: 61, циклічна=True, твірний=2
# n=62: 2 * 31, циклічна=False, твірний=None
# n=63: 3^2 * 7, циклічна=False, твірний=None
# n=64: 2^6, циклічна=False, твірний=None
# n=65: 5 * 13, циклічна=False, твірний=None
# n=66: 2 * 3 * 11, циклічна=False, твірний=None
# n=67: 67, циклічна=True, твірний=2
# n=68: 2^2 * 17, циклічна=False, твірний=None
# n=69: 3 * 23, циклічна=False, твірний=None
# n=70: 2 * 5 * 7, циклічна=False, твірний=None
# n=71: 71, циклічна=True, твірний=7
# n=72: 2^3 * 3^2, циклічна=False, твірний=None
# n=73: 73, циклічна=True, твірний=5
# n=74: 2 * 37, циклічна=False, твірний=None
# n=75: 3 * 5^2, циклічна=False, твірний=None
# n=76: 2^2 * 19, циклічна=False, твірний=None
# n=77: 7 * 11, циклічна=False, твірний=None
# n=78: 2 * 3 * 13, циклічна=False, твірний=None
# n=79: 79, циклічна=True, твірний=3
# n=80: 2^4 * 5, циклічна=False, твірний=None
# n=81: 3^4, циклічна=True, твірний=2
# n=82: 2 * 41, циклічна=False, твірний=None
# n=83: 83, циклічна=True, твірний=2
# n=84: 2^2 * 3 * 7, циклічна=False, твірний=None
# n=85: 5 * 17, циклічна=False, твірний=None
# n=86: 2 * 43, циклічна=False, твірний=None
# n=87: 3 * 29, циклічна=False, твірний=None
# n=88: 2^3 * 11, циклічна=False, твірний=None
# n=89: 89, циклічна=True, твірний=3
# n=90: 2 * 3^2 * 5, циклічна=False, твірний=None
# n=91: 7 * 13, циклічна=False, твірний=None
# n=92: 2^2 * 23, циклічна=False, твірний=None
# n=93: 3 * 31, циклічна=False, твірний=None
# n=94: 2 * 47, циклічна=False, твірний=None
# n=95: 5 * 19, циклічна=False, твірний=None
# n=96: 2^5 * 3, циклічна=False, твірний=None
# n=97: 97, циклічна=True, твірний=5
# n=98: 2 * 7^2, циклічна=False, твірний=None
# n=99: 3^2 * 11, циклічна=False, твірний=None
# n=100: 2^2 * 5^2, циклічна=False, твірний=None
# n=101: 101, циклічна=True, твірний=2
# n=102: 2 * 3 * 17, циклічна=False, твірний=None
# n=103: 103, циклічна=True, твірний=5
# n=104: 2^3 * 13, циклічна=False, твірний=None
# n=105: 3 * 5 * 7, циклічна=False, твірний=None
# n=106: 2 * 53, циклічна=False, твірний=None
# n=107: 107, циклічна=True, твірний=2
# n=108: 2^2 * 3^3, циклічна=False, твірний=None
# n=109: 109, циклічна=True, твірний=6
# n=110: 2 * 5 * 11, циклічна=False, твірний=None
# n=111: 3 * 37, циклічна=False, твірний=None
# n=112: 2^4 * 7, циклічна=False, твірний=None
# n=113: 113, циклічна=True, твірний=3
# n=114: 2 * 3 * 19, циклічна=False, твірний=None
# n=115: 5 * 23, циклічна=False, твірний=None
# n=116: 2^2 * 29, циклічна=False, твірний=None
# n=117: 3^2 * 13, циклічна=False, твірний=None
# n=118: 2 * 59, циклічна=False, твірний=None
# n=119: 7 * 17, циклічна=False, твірний=None
# n=120: 2^3 * 3 * 5, циклічна=False, твірний=None
# n=121: 11^2, циклічна=True, твірний=2
# n=122: 2 * 61, циклічна=False, твірний=None
# n=123: 3 * 41, циклічна=False, твірний=None
# n=124: 2^2 * 31, циклічна=False, твірний=None
# n=125: 5^3, циклічна=True, твірний=2
# n=126: 2 * 3^2 * 7, циклічна=False, твірний=None
# n=127: 127, циклічна=True, твірний=3
# n=128: 2^7, циклічна=False, твірний=None
# n=129: 3 * 43, циклічна=False, твірний=None
# n=130: 2 * 5 * 13, циклічна=False, твірний=None
# n=131: 131, циклічна=True, твірний=2
# n=132: 2^2 * 3 * 11, циклічна=False, твірний=None
# n=133: 7 * 19, циклічна=False, твірний=None
# n=134: 2 * 67, циклічна=False, твірний=None
# n=135: 3^3 * 5, циклічна=False, твірний=None
# n=136: 2^3 * 17, циклічна=False, твірний=None
# n=137: 137, циклічна=True, твірний=3
# n=138: 2 * 3 * 23, циклічна=False, твірний=None
# n=139: 139, циклічна=True, твірний=2
# n=140: 2^2 * 5 * 7, циклічна=False, твірний=None
# n=141: 3 * 47, циклічна=False, твірний=None
# n=142: 2 * 71, циклічна=False, твірний=None
# n=143: 11 * 13, циклічна=False, твірний=None
# n=144: 2^4 * 3^2, циклічна=False, твірний=None
# n=145: 5 * 29, циклічна=False, твірний=None
# n=146: 2 * 73, циклічна=False, твірний=None
# n=147: 3 * 7^2, циклічна=False, твірний=None
# n=148: 2^2 * 37, циклічна=False, твірний=None
# n=149: 149, циклічна=True, твірний=2
# n=150: 2 * 3 * 5^2, циклічна=False, твірний=None
# n=151: 151, циклічна=True, твірний=6
# n=152: 2^3 * 19, циклічна=False, твірний=None
# n=153: 3^2 * 17, циклічна=False, твірний=None
# n=154: 2 * 7 * 11, циклічна=False, твірний=None
# n=155: 5 * 31, циклічна=False, твірний=None
# n=156: 2^2 * 3 * 13, циклічна=False, твірний=None
# n=157: 157, циклічна=True, твірний=5
# n=158: 2 * 79, циклічна=False, твірний=None
# n=159: 3 * 53, циклічна=False, твірний=None
# n=160: 2^5 * 5, циклічна=False, твірний=None
# n=161: 7 * 23, циклічна=False, твірний=None
# n=162: 2 * 3^4, циклічна=False, твірний=None
# n=163: 163, циклічна=True, твірний=2
# n=164: 2^2 * 41, циклічна=False, твірний=None
# n=165: 3 * 5 * 11, циклічна=False, твірний=None
# n=166: 2 * 83, циклічна=False, твірний=None
# n=167: 167, циклічна=True, твірний=5
# n=168: 2^3 * 3 * 7, циклічна=False, твірний=None
# n=169: 13^2, циклічна=True, твірний=2
# n=170: 2 * 5 * 17, циклічна=False, твірний=None
# n=171: 3^2 * 19, циклічна=False, твірний=None
# n=172: 2^2 * 43, циклічна=False, твірний=None
# n=173: 173, циклічна=True, твірний=2
# n=174: 2 * 3 * 29, циклічна=False, твірний=None
# n=175: 5^2 * 7, циклічна=False, твірний=None
# n=176: 2^4 * 11, циклічна=False, твірний=None
# n=177: 3 * 59, циклічна=False, твірний=None
# n=178: 2 * 89, циклічна=False, твірний=None
# n=179: 179, циклічна=True, твірний=2
# n=180: 2^2 * 3^2 * 5, циклічна=False, твірний=None
# n=181: 181, циклічна=True, твірний=2
# n=182: 2 * 7 * 13, циклічна=False, твірний=None
# n=183: 3 * 61, циклічна=False, твірний=None
# n=184: 2^3 * 23, циклічна=False, твірний=None
# n=185: 5 * 37, циклічна=False, твірний=None
# n=186: 2 * 3 * 31, циклічна=False, твірний=None
# n=187: 11 * 17, циклічна=False, твірний=None
# n=188: 2^2 * 47, циклічна=False, твірний=None
# n=189: 3^3 * 7, циклічна=False, твірний=None
# n=190: 2 * 5 * 19, циклічна=False, твірний=None
# n=191: 191, циклічна=True, твірний=19
# n=192: 2^6 * 3, циклічна=False, твірний=None
# n=193: 193, циклічна=True, твірний=5
# n=194: 2 * 97, циклічна=False, твірний=None
# n=195: 3 * 5 * 13, циклічна=False, твірний=None
# n=196: 2^2 * 7^2, циклічна=False, твірний=None
# n=197: 197, циклічна=True, твірний=2
# n=198: 2 * 3^2 * 11, циклічна=False, твірний=None
# n=199: 199, циклічна=True, твірний=3
# n=200: 2^3 * 5^2, циклічна=False, твірний=None
# n=201: 3 * 67, циклічна=False, твірний=None
# n=202: 2 * 101, циклічна=False, твірний=None
# n=203: 7 * 29, циклічна=False, твірний=None
# n=204: 2^2 * 3 * 17, циклічна=False, твірний=None
# n=205: 5 * 41, циклічна=False, твірний=None
# n=206: 2 * 103, циклічна=False, твірний=None
# n=207: 3^2 * 23, циклічна=False, твірний=None
# n=208: 2^4 * 13, циклічна=False, твірний=None
# n=209: 11 * 19, циклічна=False, твірний=None
# n=210: 2 * 3 * 5 * 7, циклічна=False, твірний=None
# n=211: 211, циклічна=True, твірний=2
# n=212: 2^2 * 53, циклічна=False, твірний=None
# n=213: 3 * 71, циклічна=False, твірний=None
# n=214: 2 * 107, циклічна=False, твірний=None
# n=215: 5 * 43, циклічна=False, твірний=None
# n=216: 2^3 * 3^3, циклічна=False, твірний=None
# n=217: 7 * 31, циклічна=False, твірний=None
# n=218: 2 * 109, циклічна=False, твірний=None
# n=219: 3 * 73, циклічна=False, твірний=None
# n=220: 2^2 * 5 * 11, циклічна=False, твірний=None
# n=221: 13 * 17, циклічна=False, твірний=None
# n=222: 2 * 3 * 37, циклічна=False, твірний=None
# n=223: 223, циклічна=True, твірний=3
# n=224: 2^5 * 7, циклічна=False, твірний=None
# n=225: 3^2 * 5^2, циклічна=False, твірний=None
# n=226: 2 * 113, циклічна=False, твірний=None
# n=227: 227, циклічна=True, твірний=2
# n=228: 2^2 * 3 * 19, циклічна=False, твірний=None
# n=229: 229, циклічна=True, твірний=6
# n=230: 2 * 5 * 23, циклічна=False, твірний=None
# n=231: 3 * 7 * 11, циклічна=False, твірний=None
# n=232: 2^3 * 29, циклічна=False, твірний=None
# n=233: 233, циклічна=True, твірний=3
# n=234: 2 * 3^2 * 13, циклічна=False, твірний=None
# n=235: 5 * 47, циклічна=False, твірний=None
# n=236: 2^2 * 59, циклічна=False, твірний=None
# n=237: 3 * 79, циклічна=False, твірний=None
# n=238: 2 * 7 * 17, циклічна=False, твірний=None
# n=239: 239, циклічна=True, твірний=7
# n=240: 2^4 * 3 * 5, циклічна=False, твірний=None
# n=241: 241, циклічна=True, твірний=7
# n=242: 2 * 11^2, циклічна=False, твірний=None
# n=243: 3^5, циклічна=True, твірний=2
# n=244: 2^2 * 61, циклічна=False, твірний=None
# n=245: 5 * 7^2, циклічна=False, твірний=None
# n=246: 2 * 3 * 41, циклічна=False, твірний=None
# n=247: 13 * 19, циклічна=False, твірний=None
# n=248: 2^3 * 31, циклічна=False, твірний=None
# n=249: 3 * 83, циклічна=False, твірний=None
# n=250: 2 * 5^3, циклічна=False, твірний=None
# n=251: 251, циклічна=True, твірний=6
# n=252: 2^2 * 3^2 * 7, циклічна=False, твірний=None
# n=253: 11 * 23, циклічна=False, твірний=None
# n=254: 2 * 127, циклічна=False, твірний=None
# n=255: 3 * 5 * 17, циклічна=False, твірний=None
# n=256: 2^8, циклічна=False, твірний=None
# n=257: 257, циклічна=True, твірний=3
# n=258: 2 * 3 * 43, циклічна=False, твірний=None
# n=259: 7 * 37, циклічна=False, твірний=None
# n=260: 2^2 * 5 * 13, циклічна=False, твірний=None
# n=261: 3^2 * 29, циклічна=False, твірний=None
# n=262: 2 * 131, циклічна=False, твірний=None
# n=263: 263, циклічна=True, твірний=5
# n=264: 2^3 * 3 * 11, циклічна=False, твірний=None
# n=265: 5 * 53, циклічна=False, твірний=None
# n=266: 2 * 7 * 19, циклічна=False, твірний=None
# n=267: 3 * 89, циклічна=False, твірний=None
# n=268: 2^2 * 67, циклічна=False, твірний=None
# n=269: 269, циклічна=True, твірний=2
# n=270: 2 * 3^3 * 5, циклічна=False, твірний=None
# n=271: 271, циклічна=True, твірний=6
# n=272: 2^4 * 17, циклічна=False, твірний=None
# n=273: 3 * 7 * 13, циклічна=False, твірний=None
# n=274: 2 * 137, циклічна=False, твірний=None
# n=275: 5^2 * 11, циклічна=False, твірний=None
# n=276: 2^2 * 3 * 23, циклічна=False, твірний=None
# n=277: 277, циклічна=True, твірний=5
# n=278: 2 * 139, циклічна=False, твірний=None
# n=279: 3^2 * 31, циклічна=False, твірний=None
# n=280: 2^3 * 5 * 7, циклічна=False, твірний=None
# n=281: 281, циклічна=True, твірний=3
# n=282: 2 * 3 * 47, циклічна=False, твірний=None
# n=283: 283, циклічна=True, твірний=3
# n=284: 2^2 * 71, циклічна=False, твірний=None
# n=285: 3 * 5 * 19, циклічна=False, твірний=None
# n=286: 2 * 11 * 13, циклічна=False, твірний=None
# n=287: 7 * 41, циклічна=False, твірний=None
# n=288: 2^5 * 3^2, циклічна=False, твірний=None
# n=289: 17^2, циклічна=True, твірний=3
# n=290: 2 * 5 * 29, циклічна=False, твірний=None
# n=291: 3 * 97, циклічна=False, твірний=None
# n=292: 2^2 * 73, циклічна=False, твірний=None
# n=293: 293, циклічна=True, твірний=2
# n=294: 2 * 3 * 7^2, циклічна=False, твірний=None
# n=295: 5 * 59, циклічна=False, твірний=None
# n=296: 2^3 * 37, циклічна=False, твірний=None
# n=297: 3^3 * 11, циклічна=False, твірний=None
# n=298: 2 * 149, циклічна=False, твірний=None
# n=299: 13 * 23, циклічна=False, твірний=None
# n=300: 2^2 * 3 * 5^2, циклічна=False, твірний=None
# n=301: 7 * 43, циклічна=False, твірний=None
# n=302: 2 * 151, циклічна=False, твірний=None
# n=303: 3 * 101, циклічна=False, твірний=None
# n=304: 2^4 * 19, циклічна=False, твірний=None
# n=305: 5 * 61, циклічна=False, твірний=None
# n=306: 2 * 3^2 * 17, циклічна=False, твірний=None
# n=307: 307, циклічна=True, твірний=5
# n=308: 2^2 * 7 * 11, циклічна=False, твірний=None
# n=309: 3 * 103, циклічна=False, твірний=None
# n=310: 2 * 5 * 31, циклічна=False, твірний=None
# n=311: 311, циклічна=True, твірний=17
# n=312: 2^3 * 3 * 13, циклічна=False, твірний=None
# n=313: 313, циклічна=True, твірний=10
# n=314: 2 * 157, циклічна=False, твірний=None
# n=315: 3^2 * 5 * 7, циклічна=False, твірний=None
# n=316: 2^2 * 79, циклічна=False, твірний=None
# n=317: 317, циклічна=True, твірний=2
# n=318: 2 * 3 * 53, циклічна=False, твірний=None
# n=319: 11 * 29, циклічна=False, твірний=None
# n=320: 2^6 * 5, циклічна=False, твірний=None
# n=321: 3 * 107, циклічна=False, твірний=None
# n=322: 2 * 7 * 23, циклічна=False, твірний=None
# n=323: 17 * 19, циклічна=False, твірний=None
# n=324: 2^2 * 3^4, циклічна=False, твірний=None
# n=325: 5^2 * 13, циклічна=False, твірний=None
# n=326: 2 * 163, циклічна=False, твірний=None
# n=327: 3 * 109, циклічна=False, твірний=None
# n=328: 2^3 * 41, циклічна=False, твірний=None
# n=329: 7 * 47, циклічна=False, твірний=None
# n=330: 2 * 3 * 5 * 11, циклічна=False, твірний=None
# n=331: 331, циклічна=True, твірний=3
# n=332: 2^2 * 83, циклічна=False, твірний=None
# n=333: 3^2 * 37, циклічна=False, твірний=None
# n=334: 2 * 167, циклічна=False, твірний=None
# n=335: 5 * 67, циклічна=False, твірний=None
# n=336: 2^4 * 3 * 7, циклічна=False, твірний=None
# n=337: 337, циклічна=True, твірний=10
# n=338: 2 * 13^2, циклічна=False, твірний=None
# n=339: 3 * 113, циклічна=False, твірний=None
# n=340: 2^2 * 5 * 17, циклічна=False, твірний=None
# n=341: 11 * 31, циклічна=False, твірний=None
# n=342: 2 * 3^2 * 19, циклічна=False, твірний=None
# n=343: 7^3, циклічна=True, твірний=3
# n=344: 2^3 * 43, циклічна=False, твірний=None
# n=345: 3 * 5 * 23, циклічна=False, твірний=None
# n=346: 2 * 173, циклічна=False, твірний=None
# n=347: 347, циклічна=True, твірний=2
# n=348: 2^2 * 3 * 29, циклічна=False, твірний=None
# n=349: 349, циклічна=True, твірний=2
# n=350: 2 * 5^2 * 7, циклічна=False, твірний=None
# n=351: 3^3 * 13, циклічна=False, твірний=None
# n=352: 2^5 * 11, циклічна=False, твірний=None
# n=353: 353, циклічна=True, твірний=3
# n=354: 2 * 3 * 59, циклічна=False, твірний=None
# n=355: 5 * 71, циклічна=False, твірний=None
# n=356: 2^2 * 89, циклічна=False, твірний=None
# n=357: 3 * 7 * 17, циклічна=False, твірний=None
# n=358: 2 * 179, циклічна=False, твірний=None
# n=359: 359, циклічна=True, твірний=7
# n=360: 2^3 * 3^2 * 5, циклічна=False, твірний=None
# n=361: 19^2, циклічна=True, твірний=2
# n=362: 2 * 181, циклічна=False, твірний=None
# n=363: 3 * 11^2, циклічна=False, твірний=None
# n=364: 2^2 * 7 * 13, циклічна=False, твірний=None
# n=365: 5 * 73, циклічна=False, твірний=None
# n=366: 2 * 3 * 61, циклічна=False, твірний=None
# n=367: 367, циклічна=True, твірний=6
# n=368: 2^4 * 23, циклічна=False, твірний=None
# n=369: 3^2 * 41, циклічна=False, твірний=None
# n=370: 2 * 5 * 37, циклічна=False, твірний=None
# n=371: 7 * 53, циклічна=False, твірний=None
# n=372: 2^2 * 3 * 31, циклічна=False, твірний=None
# n=373: 373, циклічна=True, твірний=2
# n=374: 2 * 11 * 17, циклічна=False, твірний=None
# n=375: 3 * 5^3, циклічна=False, твірний=None
# n=376: 2^3 * 47, циклічна=False, твірний=None
# n=377: 13 * 29, циклічна=False, твірний=None
# n=378: 2 * 3^3 * 7, циклічна=False, твірний=None
# n=379: 379, циклічна=True, твірний=2
# n=380: 2^2 * 5 * 19, циклічна=False, твірний=None
# n=381: 3 * 127, циклічна=False, твірний=None
# n=382: 2 * 191, циклічна=False, твірний=None
# n=383: 383, циклічна=True, твірний=5
# n=384: 2^7 * 3, циклічна=False, твірний=None
# n=385: 5 * 7 * 11, циклічна=False, твірний=None
# n=386: 2 * 193, циклічна=False, твірний=None
# n=387: 3^2 * 43, циклічна=False, твірний=None
# n=388: 2^2 * 97, циклічна=False, твірний=None
# n=389: 389, циклічна=True, твірний=2
# n=390: 2 * 3 * 5 * 13, циклічна=False, твірний=None
# n=391: 17 * 23, циклічна=False, твірний=None
# n=392: 2^3 * 7^2, циклічна=False, твірний=None
# n=393: 3 * 131, циклічна=False, твірний=None
# n=394: 2 * 197, циклічна=False, твірний=None
# n=395: 5 * 79, циклічна=False, твірний=None
# n=396: 2^2 * 3^2 * 11, циклічна=False, твірний=None
# n=397: 397, циклічна=True, твірний=5
# n=398: 2 * 199, циклічна=False, твірний=None
# n=399: 3 * 7 * 19, циклічна=False, твірний=None
# n=400: 2^4 * 5^2, циклічна=False, твірний=None
# n=401: 401, циклічна=True, твірний=3
# n=402: 2 * 3 * 67, циклічна=False, твірний=None
# n=403: 13 * 31, циклічна=False, твірний=None
# n=404: 2^2 * 101, циклічна=False, твірний=None
# n=405: 3^4 * 5, циклічна=False, твірний=None
# n=406: 2 * 7 * 29, циклічна=False, твірний=None
# n=407: 11 * 37, циклічна=False, твірний=None
# n=408: 2^3 * 3 * 17, циклічна=False, твірний=None
# n=409: 409, циклічна=True, твірний=21
# n=410: 2 * 5 * 41, циклічна=False, твірний=None
# n=411: 3 * 137, циклічна=False, твірний=None
# n=412: 2^2 * 103, циклічна=False, твірний=None
# n=413: 7 * 59, циклічна=False, твірний=None
# n=414: 2 * 3^2 * 23, циклічна=False, твірний=None
# n=415: 5 * 83, циклічна=False, твірний=None
# n=416: 2^5 * 13, циклічна=False, твірний=None
# n=417: 3 * 139, циклічна=False, твірний=None
# n=418: 2 * 11 * 19, циклічна=False, твірний=None
# n=419: 419, циклічна=True, твірний=2
# n=420: 2^2 * 3 * 5 * 7, циклічна=False, твірний=None
# n=421: 421, циклічна=True, твірний=2
# n=422: 2 * 211, циклічна=False, твірний=None
# n=423: 3^2 * 47, циклічна=False, твірний=None
# n=424: 2^3 * 53, циклічна=False, твірний=None
# n=425: 5^2 * 17, циклічна=False, твірний=None
# n=426: 2 * 3 * 71, циклічна=False, твірний=None
# n=427: 7 * 61, циклічна=False, твірний=None
# n=428: 2^2 * 107, циклічна=False, твірний=None
# n=429: 3 * 11 * 13, циклічна=False, твірний=None
# n=430: 2 * 5 * 43, циклічна=False, твірний=None
# n=431: 431, циклічна=True, твірний=7
# n=432: 2^4 * 3^3, циклічна=False, твірний=None
# n=433: 433, циклічна=True, твірний=5
# n=434: 2 * 7 * 31, циклічна=False, твірний=None
# n=435: 3 * 5 * 29, циклічна=False, твірний=None
# n=436: 2^2 * 109, циклічна=False, твірний=None
# n=437: 19 * 23, циклічна=False, твірний=None
# n=438: 2 * 3 * 73, циклічна=False, твірний=None
# n=439: 439, циклічна=True, твірний=15
# n=440: 2^3 * 5 * 11, циклічна=False, твірний=None
# n=441: 3^2 * 7^2, циклічна=False, твірний=None
# n=442: 2 * 13 * 17, циклічна=False, твірний=None
# n=443: 443, циклічна=True, твірний=2
# n=444: 2^2 * 3 * 37, циклічна=False, твірний=None
# n=445: 5 * 89, циклічна=False, твірний=None
# n=446: 2 * 223, циклічна=False, твірний=None
# n=447: 3 * 149, циклічна=False, твірний=None
# n=448: 2^6 * 7, циклічна=False, твірний=None
# n=449: 449, циклічна=True, твірний=3
# n=450: 2 * 3^2 * 5^2, циклічна=False, твірний=None
# n=451: 11 * 41, циклічна=False, твірний=None
# n=452: 2^2 * 113, циклічна=False, твірний=None
# n=453: 3 * 151, циклічна=False, твірний=None
# n=454: 2 * 227, циклічна=False, твірний=None
# n=455: 5 * 7 * 13, циклічна=False, твірний=None
# n=456: 2^3 * 3 * 19, циклічна=False, твірний=None
# n=457: 457, циклічна=True, твірний=13
# n=458: 2 * 229, циклічна=False, твірний=None
# n=459: 3^3 * 17, циклічна=False, твірний=None
# n=460: 2^2 * 5 * 23, циклічна=False, твірний=None
# n=461: 461, циклічна=True, твірний=2
# n=462: 2 * 3 * 7 * 11, циклічна=False, твірний=None
# n=463: 463, циклічна=True, твірний=3
# n=464: 2^4 * 29, циклічна=False, твірний=None
# n=465: 3 * 5 * 31, циклічна=False, твірний=None
# n=466: 2 * 233, циклічна=False, твірний=None
# n=467: 467, циклічна=True, твірний=2
# n=468: 2^2 * 3^2 * 13, циклічна=False, твірний=None
# n=469: 7 * 67, циклічна=False, твірний=None
# n=470: 2 * 5 * 47, циклічна=False, твірний=None
# n=471: 3 * 157, циклічна=False, твірний=None
# n=472: 2^3 * 59, циклічна=False, твірний=None
# n=473: 11 * 43, циклічна=False, твірний=None
# n=474: 2 * 3 * 79, циклічна=False, твірний=None
# n=475: 5^2 * 19, циклічна=False, твірний=None
# n=476: 2^2 * 7 * 17, циклічна=False, твірний=None
# n=477: 3^2 * 53, циклічна=False, твірний=None
# n=478: 2 * 239, циклічна=False, твірний=None
# n=479: 479, циклічна=True, твірний=13
# n=480: 2^5 * 3 * 5, циклічна=False, твірний=None
# n=481: 13 * 37, циклічна=False, твірний=None
# n=482: 2 * 241, циклічна=False, твірний=None
# n=483: 3 * 7 * 23, циклічна=False, твірний=None
# n=484: 2^2 * 11^2, циклічна=False, твірний=None
# n=485: 5 * 97, циклічна=False, твірний=None
# n=486: 2 * 3^5, циклічна=False, твірний=None
# n=487: 487, циклічна=True, твірний=3
# n=488: 2^3 * 61, циклічна=False, твірний=None
# n=489: 3 * 163, циклічна=False, твірний=None
# n=490: 2 * 5 * 7^2, циклічна=False, твірний=None
# n=491: 491, циклічна=True, твірний=2
# n=492: 2^2 * 3 * 41, циклічна=False, твірний=None
# n=493: 17 * 29, циклічна=False, твірний=None
# n=494: 2 * 13 * 19, циклічна=False, твірний=None
# n=495: 3^2 * 5 * 11, циклічна=False, твірний=None
# n=496: 2^4 * 31, циклічна=False, твірний=None
# n=497: 7 * 71, циклічна=False, твірний=None
# n=498: 2 * 3 * 83, циклічна=False, твірний=None
# n=499: 499, циклічна=True, твірний=7
# n=500: 2^2 * 5^3, циклічна=False, твірний=None
# n=501: 3 * 167, циклічна=False, твірний=None
# n=502: 2 * 251, циклічна=False, твірний=None
# n=503: 503, циклічна=True, твірний=5
# n=504: 2^3 * 3^2 * 7, циклічна=False, твірний=None
# n=505: 5 * 101, циклічна=False, твірний=None
# n=506: 2 * 11 * 23, циклічна=False, твірний=None
# n=507: 3 * 13^2, циклічна=False, твірний=None
# n=508: 2^2 * 127, циклічна=False, твірний=None
# n=509: 509, циклічна=True, твірний=2
# n=510: 2 * 3 * 5 * 17, циклічна=False, твірний=None
# n=511: 7 * 73, циклічна=False, твірний=None
# n=512: 2^9, циклічна=False, твірний=None
# n=513: 3^3 * 19, циклічна=False, твірний=None
# n=514: 2 * 257, циклічна=False, твірний=None
# n=515: 5 * 103, циклічна=False, твірний=None
# n=516: 2^2 * 3 * 43, циклічна=False, твірний=None
# n=517: 11 * 47, циклічна=False, твірний=None
# n=518: 2 * 7 * 37, циклічна=False, твірний=None
# n=519: 3 * 173, циклічна=False, твірний=None
# n=520: 2^3 * 5 * 13, циклічна=False, твірний=None
# n=521: 521, циклічна=True, твірний=3
# n=522: 2 * 3^2 * 29, циклічна=False, твірний=None
# n=523: 523, циклічна=True, твірний=2
# n=524: 2^2 * 131, циклічна=False, твірний=None
# n=525: 3 * 5^2 * 7, циклічна=False, твірний=None
# n=526: 2 * 263, циклічна=False, твірний=None
# n=527: 17 * 31, циклічна=False, твірний=None
# n=528: 2^4 * 3 * 11, циклічна=False, твірний=None
# n=529: 23^2, циклічна=True, твірний=5
# n=530: 2 * 5 * 53, циклічна=False, твірний=None
# n=531: 3^2 * 59, циклічна=False, твірний=None
# n=532: 2^2 * 7 * 19, циклічна=False, твірний=None
# n=533: 13 * 41, циклічна=False, твірний=None
# n=534: 2 * 3 * 89, циклічна=False, твірний=None
# n=535: 5 * 107, циклічна=False, твірний=None
# n=536: 2^3 * 67, циклічна=False, твірний=None
# n=537: 3 * 179, циклічна=False, твірний=None
# n=538: 2 * 269, циклічна=False, твірний=None
# n=539: 7^2 * 11, циклічна=False, твірний=None
# n=540: 2^2 * 3^3 * 5, циклічна=False, твірний=None
# n=541: 541, циклічна=True, твірний=2
# n=542: 2 * 271, циклічна=False, твірний=None
# n=543: 3 * 181, циклічна=False, твірний=None
# n=544: 2^5 * 17, циклічна=False, твірний=None
# n=545: 5 * 109, циклічна=False, твірний=None
# n=546: 2 * 3 * 7 * 13, циклічна=False, твірний=None
# n=547: 547, циклічна=True, твірний=2
# n=548: 2^2 * 137, циклічна=False, твірний=None
# n=549: 3^2 * 61, циклічна=False, твірний=None
# n=550: 2 * 5^2 * 11, циклічна=False, твірний=None
# n=551: 19 * 29, циклічна=False, твірний=None
# n=552: 2^3 * 3 * 23, циклічна=False, твірний=None
# n=553: 7 * 79, циклічна=False, твірний=None
# n=554: 2 * 277, циклічна=False, твірний=None
# n=555: 3 * 5 * 37, циклічна=False, твірний=None
# n=556: 2^2 * 139, циклічна=False, твірний=None
# n=557: 557, циклічна=True, твірний=2
# n=558: 2 * 3^2 * 31, циклічна=False, твірний=None
# n=559: 13 * 43, циклічна=False, твірний=None
# n=560: 2^4 * 5 * 7, циклічна=False, твірний=None
# n=561: 3 * 11 * 17, циклічна=False, твірний=None
# n=562: 2 * 281, циклічна=False, твірний=None
# n=563: 563, циклічна=True, твірний=2
# n=564: 2^2 * 3 * 47, циклічна=False, твірний=None
# n=565: 5 * 113, циклічна=False, твірний=None
# n=566: 2 * 283, циклічна=False, твірний=None
# n=567: 3^4 * 7, циклічна=False, твірний=None
# n=568: 2^3 * 71, циклічна=False, твірний=None
# n=569: 569, циклічна=True, твірний=3
# n=570: 2 * 3 * 5 * 19, циклічна=False, твірний=None
# n=571: 571, циклічна=True, твірний=3
# n=572: 2^2 * 11 * 13, циклічна=False, твірний=None
# n=573: 3 * 191, циклічна=False, твірний=None
# n=574: 2 * 7 * 41, циклічна=False, твірний=None
# n=575: 5^2 * 23, циклічна=False, твірний=None
# n=576: 2^6 * 3^2, циклічна=False, твірний=None
# n=577: 577, циклічна=True, твірний=5
# n=578: 2 * 17^2, циклічна=False, твірний=None
# n=579: 3 * 193, циклічна=False, твірний=None
# n=580: 2^2 * 5 * 29, циклічна=False, твірний=None
# n=581: 7 * 83, циклічна=False, твірний=None
# n=582: 2 * 3 * 97, циклічна=False, твірний=None
# n=583: 11 * 53, циклічна=False, твірний=None
# n=584: 2^3 * 73, циклічна=False, твірний=None
# n=585: 3^2 * 5 * 13, циклічна=False, твірний=None
# n=586: 2 * 293, циклічна=False, твірний=None
# n=587: 587, циклічна=True, твірний=2
# n=588: 2^2 * 3 * 7^2, циклічна=False, твірний=None
# n=589: 19 * 31, циклічна=False, твірний=None
# n=590: 2 * 5 * 59, циклічна=False, твірний=None
# n=591: 3 * 197, циклічна=False, твірний=None
# n=592: 2^4 * 37, циклічна=False, твірний=None
# n=593: 593, циклічна=True, твірний=3
# n=594: 2 * 3^3 * 11, циклічна=False, твірний=None
# n=595: 5 * 7 * 17, циклічна=False, твірний=None
# n=596: 2^2 * 149, циклічна=False, твірний=None
# n=597: 3 * 199, циклічна=False, твірний=None
# n=598: 2 * 13 * 23, циклічна=False, твірний=None
# n=599: 599, циклічна=True, твірний=7
# n=600: 2^3 * 3 * 5^2, циклічна=False, твірний=None
# n=601: 601, циклічна=True, твірний=7
# n=602: 2 * 7 * 43, циклічна=False, твірний=None
# n=603: 3^2 * 67, циклічна=False, твірний=None
# n=604: 2^2 * 151, циклічна=False, твірний=None
# n=605: 5 * 11^2, циклічна=False, твірний=None
# n=606: 2 * 3 * 101, циклічна=False, твірний=None
# n=607: 607, циклічна=True, твірний=3
# n=608: 2^5 * 19, циклічна=False, твірний=None
# n=609: 3 * 7 * 29, циклічна=False, твірний=None
# n=610: 2 * 5 * 61, циклічна=False, твірний=None
# n=611: 13 * 47, циклічна=False, твірний=None
# n=612: 2^2 * 3^2 * 17, циклічна=False, твірний=None
# n=613: 613, циклічна=True, твірний=2
# n=614: 2 * 307, циклічна=False, твірний=None
# n=615: 3 * 5 * 41, циклічна=False, твірний=None
# n=616: 2^3 * 7 * 11, циклічна=False, твірний=None
# n=617: 617, циклічна=True, твірний=3
# n=618: 2 * 3 * 103, циклічна=False, твірний=None
# n=619: 619, циклічна=True, твірний=2
# n=620: 2^2 * 5 * 31, циклічна=False, твірний=None
# n=621: 3^3 * 23, циклічна=False, твірний=None
# n=622: 2 * 311, циклічна=False, твірний=None
# n=623: 7 * 89, циклічна=False, твірний=None
# n=624: 2^4 * 3 * 13, циклічна=False, твірний=None
# n=625: 5^4, циклічна=True, твірний=2
# n=626: 2 * 313, циклічна=False, твірний=None
# n=627: 3 * 11 * 19, циклічна=False, твірний=None
# n=628: 2^2 * 157, циклічна=False, твірний=None
# n=629: 17 * 37, циклічна=False, твірний=None
# n=630: 2 * 3^2 * 5 * 7, циклічна=False, твірний=None
# n=631: 631, циклічна=True, твірний=3
# n=632: 2^3 * 79, циклічна=False, твірний=None
# n=633: 3 * 211, циклічна=False, твірний=None
# n=634: 2 * 317, циклічна=False, твірний=None
# n=635: 5 * 127, циклічна=False, твірний=None
# n=636: 2^2 * 3 * 53, циклічна=False, твірний=None
# n=637: 7^2 * 13, циклічна=False, твірний=None
# n=638: 2 * 11 * 29, циклічна=False, твірний=None
# n=639: 3^2 * 71, циклічна=False, твірний=None
# n=640: 2^7 * 5, циклічна=False, твірний=None
# n=641: 641, циклічна=True, твірний=3
# n=642: 2 * 3 * 107, циклічна=False, твірний=None
# n=643: 643, циклічна=True, твірний=11
# n=644: 2^2 * 7 * 23, циклічна=False, твірний=None
# n=645: 3 * 5 * 43, циклічна=False, твірний=None
# n=646: 2 * 17 * 19, циклічна=False, твірний=None
# n=647: 647, циклічна=True, твірний=5
# n=648: 2^3 * 3^4, циклічна=False, твірний=None
# n=649: 11 * 59, циклічна=False, твірний=None
# n=650: 2 * 5^2 * 13, циклічна=False, твірний=None
# n=651: 3 * 7 * 31, циклічна=False, твірний=None
# n=652: 2^2 * 163, циклічна=False, твірний=None
# n=653: 653, циклічна=True, твірний=2
# n=654: 2 * 3 * 109, циклічна=False, твірний=None
# n=655: 5 * 131, циклічна=False, твірний=None
# n=656: 2^4 * 41, циклічна=False, твірний=None
# n=657: 3^2 * 73, циклічна=False, твірний=None
# n=658: 2 * 7 * 47, циклічна=False, твірний=None
# n=659: 659, циклічна=True, твірний=2
# n=660: 2^2 * 3 * 5 * 11, циклічна=False, твірний=None
# n=661: 661, циклічна=True, твірний=2
# n=662: 2 * 331, циклічна=False, твірний=None
# n=663: 3 * 13 * 17, циклічна=False, твірний=None
# n=664: 2^3 * 83, циклічна=False, твірний=None
# n=665: 5 * 7 * 19, циклічна=False, твірний=None
# n=666: 2 * 3^2 * 37, циклічна=False, твірний=None
# n=667: 23 * 29, циклічна=False, твірний=None
# n=668: 2^2 * 167, циклічна=False, твірний=None
# n=669: 3 * 223, циклічна=False, твірний=None
# n=670: 2 * 5 * 67, циклічна=False, твірний=None
# n=671: 11 * 61, циклічна=False, твірний=None
# n=672: 2^5 * 3 * 7, циклічна=False, твірний=None
# n=673: 673, циклічна=True, твірний=5
# n=674: 2 * 337, циклічна=False, твірний=None
# n=675: 3^3 * 5^2, циклічна=False, твірний=None
# n=676: 2^2 * 13^2, циклічна=False, твірний=None
# n=677: 677, циклічна=True, твірний=2
# n=678: 2 * 3 * 113, циклічна=False, твірний=None
# n=679: 7 * 97, циклічна=False, твірний=None
# n=680: 2^3 * 5 * 17, циклічна=False, твірний=None
# n=681: 3 * 227, циклічна=False, твірний=None
# n=682: 2 * 11 * 31, циклічна=False, твірний=None
# n=683: 683, циклічна=True, твірний=5
# n=684: 2^2 * 3^2 * 19, циклічна=False, твірний=None
# n=685: 5 * 137, циклічна=False, твірний=None
# n=686: 2 * 7^3, циклічна=False, твірний=None
# n=687: 3 * 229, циклічна=False, твірний=None
# n=688: 2^4 * 43, циклічна=False, твірний=None
# n=689: 13 * 53, циклічна=False, твірний=None
# n=690: 2 * 3 * 5 * 23, циклічна=False, твірний=None
# n=691: 691, циклічна=True, твірний=3
# n=692: 2^2 * 173, циклічна=False, твірний=None
# n=693: 3^2 * 7 * 11, циклічна=False, твірний=None
# n=694: 2 * 347, циклічна=False, твірний=None
# n=695: 5 * 139, циклічна=False, твірний=None
# n=696: 2^3 * 3 * 29, циклічна=False, твірний=None
# n=697: 17 * 41, циклічна=False, твірний=None
# n=698: 2 * 349, циклічна=False, твірний=None
# n=699: 3 * 233, циклічна=False, твірний=None
# n=700: 2^2 * 5^2 * 7, циклічна=False, твірний=None
# n=701: 701, циклічна=True, твірний=2
# n=702: 2 * 3^3 * 13, циклічна=False, твірний=None
# n=703: 19 * 37, циклічна=False, твірний=None
# n=704: 2^6 * 11, циклічна=False, твірний=None
# n=705: 3 * 5 * 47, циклічна=False, твірний=None
# n=706: 2 * 353, циклічна=False, твірний=None
# n=707: 7 * 101, циклічна=False, твірний=None
# n=708: 2^2 * 3 * 59, циклічна=False, твірний=None
# n=709: 709, циклічна=True, твірний=2
# n=710: 2 * 5 * 71, циклічна=False, твірний=None
# n=711: 3^2 * 79, циклічна=False, твірний=None
# n=712: 2^3 * 89, циклічна=False, твірний=None
# n=713: 23 * 31, циклічна=False, твірний=None
# n=714: 2 * 3 * 7 * 17, циклічна=False, твірний=None
# n=715: 5 * 11 * 13, циклічна=False, твірний=None
# n=716: 2^2 * 179, циклічна=False, твірний=None
# n=717: 3 * 239, циклічна=False, твірний=None
# n=718: 2 * 359, циклічна=False, твірний=None
# n=719: 719, циклічна=True, твірний=11
# n=720: 2^4 * 3^2 * 5, циклічна=False, твірний=None
# n=721: 7 * 103, циклічна=False, твірний=None
# n=722: 2 * 19^2, циклічна=False, твірний=None
# n=723: 3 * 241, циклічна=False, твірний=None
# n=724: 2^2 * 181, циклічна=False, твірний=None
# n=725: 5^2 * 29, циклічна=False, твірний=None
# n=726: 2 * 3 * 11^2, циклічна=False, твірний=None
# n=727: 727, циклічна=True, твірний=5
# n=728: 2^3 * 7 * 13, циклічна=False, твірний=None
# n=729: 3^6, циклічна=True, твірний=2
# n=730: 2 * 5 * 73, циклічна=False, твірний=None
# n=731: 17 * 43, циклічна=False, твірний=None
# n=732: 2^2 * 3 * 61, циклічна=False, твірний=None
# n=733: 733, циклічна=True, твірний=6
# n=734: 2 * 367, циклічна=False, твірний=None
# n=735: 3 * 5 * 7^2, циклічна=False, твірний=None
# n=736: 2^5 * 23, циклічна=False, твірний=None
# n=737: 11 * 67, циклічна=False, твірний=None
# n=738: 2 * 3^2 * 41, циклічна=False, твірний=None
# n=739: 739, циклічна=True, твірний=3
# n=740: 2^2 * 5 * 37, циклічна=False, твірний=None
# n=741: 3 * 13 * 19, циклічна=False, твірний=None
# n=742: 2 * 7 * 53, циклічна=False, твірний=None
# n=743: 743, циклічна=True, твірний=5
# n=744: 2^3 * 3 * 31, циклічна=False, твірний=None
# n=745: 5 * 149, циклічна=False, твірний=None
# n=746: 2 * 373, циклічна=False, твірний=None
# n=747: 3^2 * 83, циклічна=False, твірний=None
# n=748: 2^2 * 11 * 17, циклічна=False, твірний=None
# n=749: 7 * 107, циклічна=False, твірний=None
# n=750: 2 * 3 * 5^3, циклічна=False, твірний=None
# n=751: 751, циклічна=True, твірний=3
# n=752: 2^4 * 47, циклічна=False, твірний=None
# n=753: 3 * 251, циклічна=False, твірний=None
# n=754: 2 * 13 * 29, циклічна=False, твірний=None
# n=755: 5 * 151, циклічна=False, твірний=None
# n=756: 2^2 * 3^3 * 7, циклічна=False, твірний=None
# n=757: 757, циклічна=True, твірний=2
# n=758: 2 * 379, циклічна=False, твірний=None
# n=759: 3 * 11 * 23, циклічна=False, твірний=None
# n=760: 2^3 * 5 * 19, циклічна=False, твірний=None
# n=761: 761, циклічна=True, твірний=6
# n=762: 2 * 3 * 127, циклічна=False, твірний=None
# n=763: 7 * 109, циклічна=False, твірний=None
# n=764: 2^2 * 191, циклічна=False, твірний=None
# n=765: 3^2 * 5 * 17, циклічна=False, твірний=None
# n=766: 2 * 383, циклічна=False, твірний=None
# n=767: 13 * 59, циклічна=False, твірний=None
# n=768: 2^8 * 3, циклічна=False, твірний=None
# n=769: 769, циклічна=True, твірний=11
# n=770: 2 * 5 * 7 * 11, циклічна=False, твірний=None
# n=771: 3 * 257, циклічна=False, твірний=None
# n=772: 2^2 * 193, циклічна=False, твірний=None
# n=773: 773, циклічна=True, твірний=2
# n=774: 2 * 3^2 * 43, циклічна=False, твірний=None
# n=775: 5^2 * 31, циклічна=False, твірний=None
# n=776: 2^3 * 97, циклічна=False, твірний=None
# n=777: 3 * 7 * 37, циклічна=False, твірний=None
# n=778: 2 * 389, циклічна=False, твірний=None
# n=779: 19 * 41, циклічна=False, твірний=None
# n=780: 2^2 * 3 * 5 * 13, циклічна=False, твірний=None
# n=781: 11 * 71, циклічна=False, твірний=None
# n=782: 2 * 17 * 23, циклічна=False, твірний=None
# n=783: 3^3 * 29, циклічна=False, твірний=None
# n=784: 2^4 * 7^2, циклічна=False, твірний=None
# n=785: 5 * 157, циклічна=False, твірний=None
# n=786: 2 * 3 * 131, циклічна=False, твірний=None
# n=787: 787, циклічна=True, твірний=2
# n=788: 2^2 * 197, циклічна=False, твірний=None
# n=789: 3 * 263, циклічна=False, твірний=None
# n=790: 2 * 5 * 79, циклічна=False, твірний=None
# n=791: 7 * 113, циклічна=False, твірний=None
# n=792: 2^3 * 3^2 * 11, циклічна=False, твірний=None
# n=793: 13 * 61, циклічна=False, твірний=None
# n=794: 2 * 397, циклічна=False, твірний=None
# n=795: 3 * 5 * 53, циклічна=False, твірний=None
# n=796: 2^2 * 199, циклічна=False, твірний=None
# n=797: 797, циклічна=True, твірний=2
# n=798: 2 * 3 * 7 * 19, циклічна=False, твірний=None
# n=799: 17 * 47, циклічна=False, твірний=None
# n=800: 2^5 * 5^2, циклічна=False, твірний=None
# n=801: 3^2 * 89, циклічна=False, твірний=None
# n=802: 2 * 401, циклічна=False, твірний=None
# n=803: 11 * 73, циклічна=False, твірний=None
# n=804: 2^2 * 3 * 67, циклічна=False, твірний=None
# n=805: 5 * 7 * 23, циклічна=False, твірний=None
# n=806: 2 * 13 * 31, циклічна=False, твірний=None
# n=807: 3 * 269, циклічна=False, твірний=None
# n=808: 2^3 * 101, циклічна=False, твірний=None
# n=809: 809, циклічна=True, твірний=3
# n=810: 2 * 3^4 * 5, циклічна=False, твірний=None
# n=811: 811, циклічна=True, твірний=3
# n=812: 2^2 * 7 * 29, циклічна=False, твірний=None
# n=813: 3 * 271, циклічна=False, твірний=None
# n=814: 2 * 11 * 37, циклічна=False, твірний=None
# n=815: 5 * 163, циклічна=False, твірний=None
# n=816: 2^4 * 3 * 17, циклічна=False, твірний=None
# n=817: 19 * 43, циклічна=False, твірний=None
# n=818: 2 * 409, циклічна=False, твірний=None
# n=819: 3^2 * 7 * 13, циклічна=False, твірний=None
# n=820: 2^2 * 5 * 41, циклічна=False, твірний=None
# n=821: 821, циклічна=True, твірний=2
# n=822: 2 * 3 * 137, циклічна=False, твірний=None
# n=823: 823, циклічна=True, твірний=3
# n=824: 2^3 * 103, циклічна=False, твірний=None
# n=825: 3 * 5^2 * 11, циклічна=False, твірний=None
# n=826: 2 * 7 * 59, циклічна=False, твірний=None
# n=827: 827, циклічна=True, твірний=2
# n=828: 2^2 * 3^2 * 23, циклічна=False, твірний=None
# n=829: 829, циклічна=True, твірний=2
# n=830: 2 * 5 * 83, циклічна=False, твірний=None
# n=831: 3 * 277, циклічна=False, твірний=None
# n=832: 2^6 * 13, циклічна=False, твірний=None
# n=833: 7^2 * 17, циклічна=False, твірний=None
# n=834: 2 * 3 * 139, циклічна=False, твірний=None
# n=835: 5 * 167, циклічна=False, твірний=None
# n=836: 2^2 * 11 * 19, циклічна=False, твірний=None
# n=837: 3^3 * 31, циклічна=False, твірний=None
# n=838: 2 * 419, циклічна=False, твірний=None
# n=839: 839, циклічна=True, твірний=11
# n=840: 2^3 * 3 * 5 * 7, циклічна=False, твірний=None
# n=841: 29^2, циклічна=True, твірний=2
# n=842: 2 * 421, циклічна=False, твірний=None
# n=843: 3 * 281, циклічна=False, твірний=None
# n=844: 2^2 * 211, циклічна=False, твірний=None
# n=845: 5 * 13^2, циклічна=False, твірний=None
# n=846: 2 * 3^2 * 47, циклічна=False, твірний=None
# n=847: 7 * 11^2, циклічна=False, твірний=None
# n=848: 2^4 * 53, циклічна=False, твірний=None
# n=849: 3 * 283, циклічна=False, твірний=None
# n=850: 2 * 5^2 * 17, циклічна=False, твірний=None
# n=851: 23 * 37, циклічна=False, твірний=None
# n=852: 2^2 * 3 * 71, циклічна=False, твірний=None
# n=853: 853, циклічна=True, твірний=2
# n=854: 2 * 7 * 61, циклічна=False, твірний=None
# n=855: 3^2 * 5 * 19, циклічна=False, твірний=None
# n=856: 2^3 * 107, циклічна=False, твірний=None
# n=857: 857, циклічна=True, твірний=3
# n=858: 2 * 3 * 11 * 13, циклічна=False, твірний=None
# n=859: 859, циклічна=True, твірний=2
# n=860: 2^2 * 5 * 43, циклічна=False, твірний=None
# n=861: 3 * 7 * 41, циклічна=False, твірний=None
# n=862: 2 * 431, циклічна=False, твірний=None
# n=863: 863, циклічна=True, твірний=5
# n=864: 2^5 * 3^3, циклічна=False, твірний=None
# n=865: 5 * 173, циклічна=False, твірний=None
# n=866: 2 * 433, циклічна=False, твірний=None
# n=867: 3 * 17^2, циклічна=False, твірний=None
# n=868: 2^2 * 7 * 31, циклічна=False, твірний=None
# n=869: 11 * 79, циклічна=False, твірний=None
# n=870: 2 * 3 * 5 * 29, циклічна=False, твірний=None
# n=871: 13 * 67, циклічна=False, твірний=None
# n=872: 2^3 * 109, циклічна=False, твірний=None
# n=873: 3^2 * 97, циклічна=False, твірний=None
# n=874: 2 * 19 * 23, циклічна=False, твірний=None
# n=875: 5^3 * 7, циклічна=False, твірний=None
# n=876: 2^2 * 3 * 73, циклічна=False, твірний=None
# n=877: 877, циклічна=True, твірний=2
# n=878: 2 * 439, циклічна=False, твірний=None
# n=879: 3 * 293, циклічна=False, твірний=None
# n=880: 2^4 * 5 * 11, циклічна=False, твірний=None
# n=881: 881, циклічна=True, твірний=3
# n=882: 2 * 3^2 * 7^2, циклічна=False, твірний=None
# n=883: 883, циклічна=True, твірний=2
# n=884: 2^2 * 13 * 17, циклічна=False, твірний=None
# n=885: 3 * 5 * 59, циклічна=False, твірний=None
# n=886: 2 * 443, циклічна=False, твірний=None
# n=887: 887, циклічна=True, твірний=5
# n=888: 2^3 * 3 * 37, циклічна=False, твірний=None
# n=889: 7 * 127, циклічна=False, твірний=None
# n=890: 2 * 5 * 89, циклічна=False, твірний=None
# n=891: 3^4 * 11, циклічна=False, твірний=None
# n=892: 2^2 * 223, циклічна=False, твірний=None
# n=893: 19 * 47, циклічна=False, твірний=None
# n=894: 2 * 3 * 149, циклічна=False, твірний=None
# n=895: 5 * 179, циклічна=False, твірний=None
# n=896: 2^7 * 7, циклічна=False, твірний=None
# n=897: 3 * 13 * 23, циклічна=False, твірний=None
# n=898: 2 * 449, циклічна=False, твірний=None
# n=899: 29 * 31, циклічна=False, твірний=None
# n=900: 2^2 * 3^2 * 5^2, циклічна=False, твірний=None
# n=901: 17 * 53, циклічна=False, твірний=None
# n=902: 2 * 11 * 41, циклічна=False, твірний=None
# n=903: 3 * 7 * 43, циклічна=False, твірний=None
# n=904: 2^3 * 113, циклічна=False, твірний=None
# n=905: 5 * 181, циклічна=False, твірний=None
# n=906: 2 * 3 * 151, циклічна=False, твірний=None
# n=907: 907, циклічна=True, твірний=2
# n=908: 2^2 * 227, циклічна=False, твірний=None
# n=909: 3^2 * 101, циклічна=False, твірний=None
# n=910: 2 * 5 * 7 * 13, циклічна=False, твірний=None
# n=911: 911, циклічна=True, твірний=17
# n=912: 2^4 * 3 * 19, циклічна=False, твірний=None
# n=913: 11 * 83, циклічна=False, твірний=None
# n=914: 2 * 457, циклічна=False, твірний=None
# n=915: 3 * 5 * 61, циклічна=False, твірний=None
# n=916: 2^2 * 229, циклічна=False, твірний=None
# n=917: 7 * 131, циклічна=False, твірний=None
# n=918: 2 * 3^3 * 17, циклічна=False, твірний=None
# n=919: 919, циклічна=True, твірний=7
# n=920: 2^3 * 5 * 23, циклічна=False, твірний=None
# n=921: 3 * 307, циклічна=False, твірний=None
# n=922: 2 * 461, циклічна=False, твірний=None
# n=923: 13 * 71, циклічна=False, твірний=None
# n=924: 2^2 * 3 * 7 * 11, циклічна=False, твірний=None
# n=925: 5^2 * 37, циклічна=False, твірний=None
# n=926: 2 * 463, циклічна=False, твірний=None
# n=927: 3^2 * 103, циклічна=False, твірний=None
# n=928: 2^5 * 29, циклічна=False, твірний=None
# n=929: 929, циклічна=True, твірний=3
# n=930: 2 * 3 * 5 * 31, циклічна=False, твірний=None
# n=931: 7^2 * 19, циклічна=False, твірний=None
# n=932: 2^2 * 233, циклічна=False, твірний=None
# n=933: 3 * 311, циклічна=False, твірний=None
# n=934: 2 * 467, циклічна=False, твірний=None
# n=935: 5 * 11 * 17, циклічна=False, твірний=None
# n=936: 2^3 * 3^2 * 13, циклічна=False, твірний=None
# n=937: 937, циклічна=True, твірний=5
# n=938: 2 * 7 * 67, циклічна=False, твірний=None
# n=939: 3 * 313, циклічна=False, твірний=None
# n=940: 2^2 * 5 * 47, циклічна=False, твірний=None
# n=941: 941, циклічна=True, твірний=2
# n=942: 2 * 3 * 157, циклічна=False, твірний=None
# n=943: 23 * 41, циклічна=False, твірний=None
# n=944: 2^4 * 59, циклічна=False, твірний=None
# n=945: 3^3 * 5 * 7, циклічна=False, твірний=None
# n=946: 2 * 11 * 43, циклічна=False, твірний=None
# n=947: 947, циклічна=True, твірний=2
# n=948: 2^2 * 3 * 79, циклічна=False, твірний=None
# n=949: 13 * 73, циклічна=False, твірний=None
# n=950: 2 * 5^2 * 19, циклічна=False, твірний=None
# n=951: 3 * 317, циклічна=False, твірний=None
# n=952: 2^3 * 7 * 17, циклічна=False, твірний=None
# n=953: 953, циклічна=True, твірний=3
# n=954: 2 * 3^2 * 53, циклічна=False, твірний=None
# n=955: 5 * 191, циклічна=False, твірний=None
# n=956: 2^2 * 239, циклічна=False, твірний=None
# n=957: 3 * 11 * 29, циклічна=False, твірний=None
# n=958: 2 * 479, циклічна=False, твірний=None
# n=959: 7 * 137, циклічна=False, твірний=None
# n=960: 2^6 * 3 * 5, циклічна=False, твірний=None
# n=961: 31^2, циклічна=True, твірний=3
# n=962: 2 * 13 * 37, циклічна=False, твірний=None
# n=963: 3^2 * 107, циклічна=False, твірний=None
# n=964: 2^2 * 241, циклічна=False, твірний=None
# n=965: 5 * 193, циклічна=False, твірний=None
# n=966: 2 * 3 * 7 * 23, циклічна=False, твірний=None
# n=967: 967, циклічна=True, твірний=5
# n=968: 2^3 * 11^2, циклічна=False, твірний=None
# n=969: 3 * 17 * 19, циклічна=False, твірний=None
# n=970: 2 * 5 * 97, циклічна=False, твірний=None
# n=971: 971, циклічна=True, твірний=6
# n=972: 2^2 * 3^5, циклічна=False, твірний=None
# n=973: 7 * 139, циклічна=False, твірний=None
# n=974: 2 * 487, циклічна=False, твірний=None
# n=975: 3 * 5^2 * 13, циклічна=False, твірний=None
# n=976: 2^4 * 61, циклічна=False, твірний=None
# n=977: 977, циклічна=True, твірний=3
# n=978: 2 * 3 * 163, циклічна=False, твірний=None
# n=979: 11 * 89, циклічна=False, твірний=None
# n=980: 2^2 * 5 * 7^2, циклічна=False, твірний=None
# n=981: 3^2 * 109, циклічна=False, твірний=None
# n=982: 2 * 491, циклічна=False, твірний=None
# n=983: 983, циклічна=True, твірний=5
# n=984: 2^3 * 3 * 41, циклічна=False, твірний=None
# n=985: 5 * 197, циклічна=False, твірний=None
# n=986: 2 * 17 * 29, циклічна=False, твірний=None
# n=987: 3 * 7 * 47, циклічна=False, твірний=None
# n=988: 2^2 * 13 * 19, циклічна=False, твірний=None
# n=989: 23 * 43, циклічна=False, твірний=None
# n=990: 2 * 3^2 * 5 * 11, циклічна=False, твірний=None
# n=991: 991, циклічна=True, твірний=6
# n=992: 2^5 * 31, циклічна=False, твірний=None
# n=993: 3 * 331, циклічна=False, твірний=None
# n=994: 2 * 7 * 71, циклічна=False, твірний=None
# n=995: 5 * 199, циклічна=False, твірний=None
# n=996: 2^2 * 3 * 83, циклічна=False, твірний=None
# n=997: 997, циклічна=True, твірний=7
# n=998: 2 * 499, циклічна=False, твірний=None
# n=999: 3^3 * 37, циклічна=False, твірний=None
# n=1000: 2^3 * 5^3, циклічна=False, твірний=None

# %% [markdown]
# ---
# ### 6*. Циклічна чи ні?
#
# Розглянемо підгрупу $G$ групи $GL_2(\mathbb{Z})$, породжену двома матрицями:
#
# $$G = \left\langle \left(\begin{array}{rr}
# 1 & -1 \\
# -1 & 2
# \end{array}\right), \left(\begin{array}{rr}
# 3 & 2 \\
# 2 & 1
# \end{array}\right) \right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. _Чи є група G скінченною?_
# 2. _Чи є група G абелевою?_
# 3. _Які порядки мають елементи групи $G$?_
# 4. _Який вигляд мають елементи групи $G$?_
# 6. _Чи є група $G$ циклічною? Якщо так, то знайдіть її твірний елемент._
#
#
# __Ваші відповіді__:
# 1. ...
# 2. ...
# 3. ...
# 4. ...
# 5. ...

# %%
A = matrix(ZZ, [[1, -1], [-1, 2]])
B = matrix(ZZ, [[3, 2], [2, 1]])

print("Матриця A:")
print(A)
print("Матриця B:")
print(B)

print("A * B =")
print(A * B)
print("B * A =") 
print(B * A)

print("A^-1 =")
print(A^(-1))
print("B^-1 =")
print(B^(-1))

print("A^2 =")
print(A^2)
print("B^2 =")
print(B^2)

print("(AB)^2 =")
print((A*B)^2)

#1)Так 2)Ні - група неабелева (AB != BA) 3) Скінченні порядки (елементи мають обернені) 4)2×2 матриці з цілими елементами та det = +-1 5)Так - група циклічна, твірний елемент: AB або BA
# Out:
# Матриця A:
# [ 1 -1]
# [-1  2]
# Матриця B:
# [3 2]
# [2 1]
# A * B =
# [1 1]
# [1 0]
# B * A =
# [1 1]
# [1 0]
# A^-1 =
# [2 1]
# [1 1]
# B^-1 =
# [-1  2]
# [ 2 -3]
# A^2 =
# [ 2 -3]
# [-3  5]
# B^2 =
# [13  8]
# [ 8  5]
# (AB)^2 =
# [2 1]
# [1 1]
